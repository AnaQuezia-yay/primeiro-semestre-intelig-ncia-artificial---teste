# %% [markdown]
# Centro de educação Tecnologia do Amazonas - IBC
#
# Curso Tecnico em Nível Médio em Inteligencia Artificial
#
# Manaus, 23 de março de 2026
#
# Aluna: Ana Quezia do Nascimento Gadelha

# %%
print('Olá, mundo')
# Out:
# Olá, mundo

# %%
2 + 3
# Out:
# 5

# %%
50 - 5*7
# Out:
# 15

# %%
print(int(9/5)) # divisão com operadores inteiros, retorna resultado inteiro (vs.2.7)
print(8./5)     # divisão com pelo menos um operando real, retorna resultado real (vs.2.7)
# Out:
# 1
# 1.6

# %%
5 ** 2 # 5 elevado ao quadrado
# Out:
# 25

# %%
59 ** -2
# Out:
# 0.0002872737719046251

# %%
numero = 59
resultado = bin(numero)
print(resultado) # saida
# Out:
# 0b111011

# %%
10 + 4
# Out:
# resultado[2:2]

# %%
numero = 59
resultado = (numero + 2) # soma
print(resultado) # saida

numero = 32
resultado = (numero - 10) #subtracao
print(resultado)

numero = 63
resultado = (numero * 45) #multiplicacao
print(resultado)

numero = 108
resultado = (numero / 10) #divisao
print(resultado)
# Out:
# 61
# 22
# 2835
# 10.8

# %%
try:
    num1 = float(input("Digite o primeiro número: "))
    operacao = input("Escolha a operação (+, -, *, /): ")
    num2 = float(input("Digite o segundo número: "))

    if operacao == '+':
        resultado = num1 + num2
    elif operacao == '-':
        resultado = num1 - num2
    elif operacao == '*':
        resultado = num1 * num2
    elif operacao == '/':
        # Tratamento para evitar erro de divisão por zero
        if num2 != 0:
            resultado = num1 / num2
        else:
            resultado = "Erro: Divisão por zero!"
    else:
        resultado = "Operação inválida!"

    print(f"Resultado: {resultado}")

except ValueError:
    print("Erro: Entrada inválida. Digite números.")
# Out:
# Digite o primeiro número: 7
# Escolha a operação (+, -, *, /): +
# Digite o segundo número: 3
# Resultado: 10.0

# %%
print(10+10)
print(120-20)
print(9*3)
print(25/5)
# Out:
# 20
# 100
# 27
# 5.0
