# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaQuezia-yay/primeiro-semestre-intelig-ncia-artificial---teste/blob/main/primeiro_codigo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Centro de educação Tecnologia do Amazonas - IBC
#
# Manaus, 17 de março de 2026
#
# Aluna: Ana Quezia do Nascimento Gadelha

# %%
import time
print(time.ctime())
# Out:
# Wed Mar 18 14:20:10 2026

# %%
s = 10
time.sleep(s)
print(time.ctime())
# Out:
# Wed Mar 18 14:20:21 2026

# %%
print("Olá, mundo")
# Out:
# Olá, mundo

# %% [markdown]
# **negrito**
#
# *italico*
#
# ~riscada~

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$
#
# $e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$

# %% [markdown]
# #**Expressões Matemáticas Básicas**

# %%
print(f"10 + 5 = {10 + 5}") #soma
print(f"50 / 2 = {50 / 2}") #divisão
print(f"2 ** 3 = {2 ** 3}") #potenciação
print(f"10 % 3 = {10 % 3}") #módulo
# Out:
# 10 + 5 = 15
# 50 / 2 = 25.0
# 2 ** 3 = 8
# 10 % 3 = 1
