# %% [markdown]
# Centro de educação Tecnologia do Amazonas - IBC
#
# Curso Tecnico em Nível Médio em Inteligencia Artificial
#
# Manaus, 24 de março de 2026
#
# Aluna: Ana Quezia do Nascimento Gadelha

# %%
num1, num2 = 0, 0
print('Ola, mundo!!')

print( 5 + 5 - 2)
print(num1)

print(5 ** 2)
print(num2)
# Out:
# Ola, mundo!!
# 8
# 0
# 25
# 0

# %%
def dobro(x):
   print(x * 2)

dobro(125)
# Out:
# 250

# %%
x = 1
if x == 1:
    # recuo de 4 espaços em branco
    print("x é 1.")
y = 33
# Out:
# x é 1.

# %%
print("Curso Técnico em Nível Médio em Inteligência Artificial - turma 2026.1")
# Out:
# Curso Técnico em Nível Médio em Inteligência Artificial - turma 2026.1
